# %% [raw]
# Explain different types of arguments in Python functions with examples.

# %% [markdown]
# ### 1. Types of Arguments

# %% [raw]
# Python supports different kinds of parameters:

# %% [raw]
# Positional arguments → matched by order.
#
# Keyword arguments → matched by name.

# %% [raw]
# a) Positional arguments (order matters)

# %%
def multiply(x, y):
    return x * y

print(multiply(3, 4))
# Out:
# 12

# %% [raw]
# Positional arguments with default value

# %%
def multiply(x, y=5):
    return x * y

print(multiply(3))
# Out:
# 15

# %% [raw]
# Calculate compound interest given principal, rate and time with defalut values

# %%
def cal_interest(principal, rate=5, time=3):
    amount = principal * (1 + rate/100) ** time
    interest = amount - principal
    return interest

interest = cal_interest(30000)
print("The compound interest is:", interest)
interest = cal_interest(30000, 10)
print("The compound interest is:", interest)
interest = cal_interest(30000, 10, 4)
print("The compound interest is:", interest)

# %% [raw]
# b) Keyword arguments (name=value)

# %%
def student_info(name, age):
    print(f"Name: {name}, Age: {age}")

student_info(age=32, name="Ravi")
# Out:
# Name: Ravi, Age: 32

# %% [raw]
# Keyword arguments with default value

# %%
def student_info(name, age = 20):
    print(f"Name: {name}, Age: {age}")

student_info(name="Ravi")
# Out:
# Name: Ravi, Age: 20

# %%
def diff(a,b):
    return a-b

c = diff(20,10)
print(c)
c = diff(b = 10, a = 20)
print(c)
# Out:
# 10
# 10

# %%
def student_info(name, course="Python"):
    print(f"Name: {name}, Course: {course}")

student_info("Anu")
student_info("Anu", "Data Science")
# Out:
# Name: Anu, Course: Python
# Name: Anu, Course: Data Science

# %% [raw]
# c) Variable length arguments:

# %% [raw]
# i) Multiple Positional Arguments (*args)
# *args allows us to pass any number of positional arguments.

# %%
def add_numbers(*nums):
    total = 0
    for n in nums:
        total += n
    return total

print(add_numbers(10, 20))
print(add_numbers(1, 2, 3, 4, 5))
print(add_numbers())
# Out:
# 30
# 15
# 0

# %% [raw]
# Mixing Normal Arguments and *args

# %%
def add_numbers(a, *nums):
    total = 0
    for n in nums:
        total += n
    total += a
    return total

print(add_numbers(10))
print(add_numbers(10, 20, 40))
print(add_numbers())
# Out:
# 10
# 70
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 10
#       8 print(add_numbers(10))
#       9 print(add_numbers(10, 20, 40))
# ---> 10 print(add_numbers())
#
# TypeError: add_numbers() missing 1 required positional argument: 'a'

# %%
def add_numbers(a=20, *nums):
    total = 0
    for n in nums:
        total += n
    total += a
    return total

print(add_numbers(10))
print(add_numbers(10, 20, 40))
print(add_numbers())
# Out:
# 10
# 70
# 20

# %% [raw]
# ii) Multiple Keyword Arguments (**kwargs)
# **kwargs allows us to pass any number of keyword arguments.

# %%
def student_info(**details):
    for key, value in details.items():
        print(f"{key}: {value}")

student_info(name="Meena", age=20, course="Python")
student_info(name="Radha", course="Java")
# Out:
# name: Meena
# age: 20
# course: Python
# name: Radha
# course: Java

# %% [raw]
# Mixing Normal Arguments and **kwargs

# %%
def employee(name, **details):
    print("Name:", name)
    for key, value in details.items():
        print(key, ":", value)

employee("Kiran", salary=40000, department="IT", city="Bangalore")
# Out:
# Name: Kiran
# salary : 40000
# department : IT
# city : Bangalore

# %% [markdown]
# ### 2. Scope of Variables

# %% [raw]
# a) Local variable → Declared inside a function, can only be accessed within that function.

# %%
def my_function():
    x = 10   # local variable
    print("Inside function, x =", x)

my_function()
# print(x)  # ❌ Error: x is local, not accessible outside
# Out:
# Inside function, x = 10

# %% [raw]
# b) Global variable → Declared outside any function, accessible anywhere in the program.

# %%
x = 50   # global variable

def my_function():
    print("Inside function, x =", x)

my_function()
print("Outside function, x =", x)
# Out:
# Inside function, x = 50
# Outside function, x = 50

# %% [raw]
# c) Local Variable Shadows Global Variable.

# %%
x = 20

def my_function():
    x = 99   # local variable with same name
    print("Inside function, x =", x)

my_function()
print("Outside function, x =", x)
# Out:
# Inside function, x = 99
# Outside function, x = 20

# %% [raw]
# d) Modifying Global Variable Inside Function.

# %%
x = 100

def modify():
    global x   # declare x as global
    x = x + 50
    print("Inside function, x =", x)

modify()
print("Outside function, x =", x)

# %% [raw]
# e) Nested Functions – nonlocal Keyword.

# %%
def outer():
    x = 30
    
    def inner():
        nonlocal x
        x = 40
        print("Inside inner:", x)
    
    inner()
    print("Inside outer:", x)

outer()
# Out:
# Inside inner: 40
# Inside outer: 40
