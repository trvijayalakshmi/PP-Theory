# %% [raw]
# 1. Write a Python code to merge two given file contents into a third file.

# %%
file2 = open('sample2.txt','w') 
file2.write("\nThis content is copyrighted")

file1 = open("sample1.txt",'r')
file2 = open("sample2.txt",'r')
output_file = open("merged.txt",'w')

for line in file1:
    output_file.write(line)
for line in file2:
    output_file.write(line)

print("Files merged successfully")
output_file = open("merged.txt",'r')
print(output_file.read())
# Out:
# Files merged successfully
# This is the write command
# It allows us to write in a particular file
# any information can be written into a file
# This content is copyrighted

# %% [raw]
# 2. Write a program that reads a file and displays the number of words, number of vowels, blank spaces, lower case letters and uppercase letters.

# %%
file = open('sample1.txt','r')
num_words = 0
num_vowels = 0
num_spaces = 0
num_lower = 0
num_upper = 0

for line in file:
    num_words += len(line.split())
    for char in line:
        if char.lower() in 'aeiou':
            num_vowels = num_vowels + 1
        if char == ' ':
            num_spaces = num_spaces + 1
        if char.islower():
            num_lower = num_lower + 1
        if char.isupper():
            num_upper = num_upper + 1
        
print(f"Number of words: {num_words}")
print(f"Number of vowels: {num_vowels}")   
print(f"Number of spaces: {num_spaces}")
print(f"Number of lowercase letters: {num_lower}")
print(f"Number of uppercase letters: {num_upper}")
# Out:
# Number of words: 22
# Number of vowels: 37
# Number of spaces: 19
# Number of lowercase letters: 88
# Number of uppercase letters: 2

# %% [raw]
# 3.  Write a Python code to Read text from a text file, find the word with most number of occurrences

# %%
file = open('sample1.txt','r') 
word_counts = {}
most_common_word = None
max_occurrences = 0

for line in file:
    words = line.strip().split()
    for word in words:
        if word in word_counts:
            word_counts[word] += 1
        else:
            word_counts[word] = 1

        if word_counts[word] > max_occurrences:
            max_occurrences = word_counts[word]
            most_common_word = word
        
print(f"The most common word is '{most_common_word}' with {max_occurrences} occurrences.")
# Out:
# The most common word is 'write' with 2 occurrences.

# %% [raw]
# 4. Write a Python code to open a given file and to check for given words present in it and display on found.

# %%
file = open('sample1.txt','r') 
words_to_search = ["write", "file", "Python"]

content = file.read().lower()  # Convert to lowercase for case-insensitive search            
found_words = []
for i in words_to_search:
    if i.lower() in content:
        print(f"Found: {i}")
        found_words.append(i)
    else:
        print(f"Not Found: {i}")
print(found_words)
# Out:
# Found: write
# Found: file
# Not Found: Python
# ['write', 'file']
